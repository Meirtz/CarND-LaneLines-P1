# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline
import pylab 
pylab.rcParams['figure.figsize'] = (15, 9)

import os

img_pathes = ["test_images/" + img for img in os.listdir("test_images/")]
for img_path in img_pathes:
    if "output" in img_path:
        img = mpimg.imread(img_path)
        plt.figure()
        plt.imshow(img)
        plt.show()

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./examples/P1_example.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./examples/P1_example.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./examples/raw-lines-example.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./examples/raw-lines-example.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./test_videos/solidWhiteRight.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./test_videos/solidWhiteRight.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./test_videos/solidYellowLeft.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./test_videos/solidYellowLeft.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./test_videos/challenge.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./test_videos/challenge.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./test_videos_output/solidWhiteRight.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./test_videos_output/solidWhiteRight.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./test_videos_output/solidYellowLeft.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./test_videos_output/solidYellowLeft.mp4" type="video/mp4">
# </video>

# %%
# %%HTML
# <video width="960" height="540" controls>
#   <source src="./test_videos_output/challenge.mp4" type="video/mp4">
# </video>
# Out:
# <video width="960" height="540" controls>
#   <source src="./test_videos_output/challenge.mp4" type="video/mp4">
# </video>
